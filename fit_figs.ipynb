# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
# import datafiles
with open('res/2-14 Traces/2-15_Standard Code_favg_traces_T=1000_N=10_b=2_l=3.5.pickle', 'rb') as handle:
    standard_df = pickle.load(handle)
    
with open('res/2-14 Traces/2-15_Fast Fail_favg_traces_T=1000_N=10_b=2_l=3.5.pickle', 'rb') as handle:
    fastfail_df = pickle.load(handle)
    
with open('res/2-14 Traces/2-15_Colorado_favg_traces_T=1000_N=10_b=2_l=3.5.pickle', 'rb') as handle:
    colorado_df = pickle.load(handle)

# %%
ax1 = sns.tsplot(data=colorado_df, time='time', value='value', unit='sim', condition='code', color='red')
ax2 = sns.tsplot(data=standard_df, time='time', value='value', unit='sim', condition='code', color='blue')
ax3 = sns.tsplot(data=fastfail_df, time='time', value='value', unit='sim', condition='code', color='green')
plt.legend()
plt.yscale('log')
plt.title('Mean Fitness vs Time (10 Simulations)')
plt.xlabel('Time (in generations)')
plt.ylabel('Fitness')
plt.savefig('res/2-15_F_avg_T=1000_b=2_l=3.5.pdf', bbox_inches='tight')
plt.show()
