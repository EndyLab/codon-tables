# %%
import numpy as np
from scipy.interpolate import interp1d as interp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from src.thunderflask import thunderflask
from src.bacteria import strain
from src.ffgen import ffgen
from src.ffgen_isaac import ffgen
from src.redGen import reductionist
from src.codonTable import codonTable
from src.codonUtils import utils
from src.bacteria import strain
import pickle
from src.codonOptimizer import tableOptimizer
from queue import Queue as queue
from random import choice
from matplotlib.colors import LinearSegmentedColormap as LSC
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cProfile
import copy
import random

# %%
rc = utils.standardTable
#Break table into dictionaries for each amino acid
Fblock = dict((key,value) for key, value in rc.items() if value == 'F')
Lblock = dict((key,value) for key, value in rc.items() if value == 'L')
Sblock = dict((key,value) for key, value in rc.items() if value == 'S')
Yblock = dict((key,value) for key, value in rc.items() if value == 'Y')
Cblock = dict((key,value) for key, value in rc.items() if value == 'C')
Wblock = dict((key,value) for key, value in rc.items() if value == 'W')
Pblock = dict((key,value) for key, value in rc.items() if value == 'P')
Hblock = dict((key,value) for key, value in rc.items() if value == 'H')
Qblock = dict((key,value) for key, value in rc.items() if value == 'Q')
Rblock = dict((key,value) for key, value in rc.items() if value == 'R')
Iblock = dict((key,value) for key, value in rc.items() if value == 'I')
Mblock = dict((key,value) for key, value in rc.items() if value == 'M')
Tblock = dict((key,value) for key, value in rc.items() if value == 'T')
Vblock = dict((key,value) for key, value in rc.items() if value == 'V')
Nblock = dict((key,value) for key, value in rc.items() if value == 'N')
Ablock = dict((key,value) for key, value in rc.items() if value == 'A')
Dblock = dict((key,value) for key, value in rc.items() if value == 'D')
Eblock = dict((key,value) for key, value in rc.items() if value == 'E')
Gblock = dict((key,value) for key, value in rc.items() if value == 'G')
Kblock = dict((key,value) for key, value in rc.items() if value == 'K')
stopBlock = dict((key,value) for key, value in rc.items() if value == '*')
blockArray = [Fblock, Lblock, Sblock, Yblock, Cblock, Wblock, Pblock, Hblock, Qblock, Rblock,
                Iblock, Mblock, Tblock, Vblock, Nblock, Ablock, Dblock, Eblock, Gblock, Kblock, stopBlock]
        
#Iterate through all amino acid blocks selecting one key and setting the rest map to stop
choices = ['UUU','UCA','UAC','UGG','CUC','CCG','CAU','CGA','AUA','ACU','AAG','GUG','GCC','GAA','GGU']
choices2 = []
for i in range (len(blockArray)):
    choices2.append(random.choice(list(blockArray[i])))
    for key in blockArray[i]: 
        if key not in choices:
            blockArray[i][key] = '*'
reductionist15 = {}
reductionist16 = {}
reductionist17 = {}
reductionist18 = {}
reductionist19 = {}
reductionist20 = {}
for i in range (len(blockArray)):
    reductionist15.update(blockArray[i])
reductionist16.update(reductionist15)
reductionist16['AAU'] = 'N'
reductionist17.update(reductionist16)  
reductionist17['UGC'] = 'C'
reductionist18.update(reductionist17) 
reductionist18['AUG'] = 'M'
reductionist19.update(reductionist18) 
reductionist19['GAU'] = 'D'
reductionist20.update(reductionist19)
reductionist20['CAG'] ='Q'

# %%
reductionist20Table = codonTable(reductionist20)
reductionist19Table = codonTable(reductionist19)
reductionist18Table = codonTable(reductionist18)
reductionist17Table = codonTable(reductionist17)
reductionist16Table = codonTable(reductionist16)
reductionist15Table = codonTable(reductionist15)

# %%
reductionist19Table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : F  UCU : *  UAU : *  UGU : *
#   C  UUC : *  UCC : *  UAC : Y  UGC : C
#   A  UUA : *  UCA : S  UAA : *  UGA : *
#   G  UUG : *  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : L  CCC : *  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : *  CGA : R
#   G  CUG : *  CCG : P  CAG : *  CGG : *
# A U  AUU : *  ACU : T  AAU : N  AGU : *
#   C  AUC : *  ACC : *  AAC : *  AGC : *
#   A  AUA : I  ACA : *  AAA : *  AGA : *
#   G  AUG : M  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : D  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : *  GCA : *  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
reductionist18Table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : F  UCU : *  UAU : *  UGU : *
#   C  UUC : *  UCC : *  UAC : Y  UGC : C
#   A  UUA : *  UCA : S  UAA : *  UGA : *
#   G  UUG : *  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : L  CCC : *  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : *  CGA : R
#   G  CUG : *  CCG : P  CAG : *  CGG : *
# A U  AUU : *  ACU : T  AAU : N  AGU : *
#   C  AUC : *  ACC : *  AAC : *  AGC : *
#   A  AUA : I  ACA : *  AAA : *  AGA : *
#   G  AUG : M  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : *  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : *  GCA : *  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
reductionist17Table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : F  UCU : *  UAU : *  UGU : *
#   C  UUC : *  UCC : *  UAC : Y  UGC : C
#   A  UUA : *  UCA : S  UAA : *  UGA : *
#   G  UUG : *  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : L  CCC : *  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : *  CGA : R
#   G  CUG : *  CCG : P  CAG : *  CGG : *
# A U  AUU : *  ACU : T  AAU : N  AGU : *
#   C  AUC : *  ACC : *  AAC : *  AGC : *
#   A  AUA : I  ACA : *  AAA : *  AGA : *
#   G  AUG : *  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : *  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : *  GCA : *  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
reductionist16Table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : F  UCU : *  UAU : *  UGU : *
#   C  UUC : *  UCC : *  UAC : Y  UGC : *
#   A  UUA : *  UCA : S  UAA : *  UGA : *
#   G  UUG : *  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : L  CCC : *  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : *  CGA : R
#   G  CUG : *  CCG : P  CAG : *  CGG : *
# A U  AUU : *  ACU : T  AAU : N  AGU : *
#   C  AUC : *  ACC : *  AAC : *  AGC : *
#   A  AUA : I  ACA : *  AAA : *  AGA : *
#   G  AUG : *  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : *  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : *  GCA : *  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
reductionist15Table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : F  UCU : *  UAU : *  UGU : *
#   C  UUC : *  UCC : *  UAC : Y  UGC : *
#   A  UUA : *  UCA : S  UAA : *  UGA : *
#   G  UUG : *  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : L  CCC : *  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : *  CGA : R
#   G  CUG : *  CCG : P  CAG : *  CGG : *
# A U  AUU : *  ACU : T  AAU : *  AGU : *
#   C  AUC : *  ACC : *  AAC : *  AGC : *
#   A  AUA : I  ACA : *  AAA : *  AGA : *
#   G  AUG : *  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : *  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : *  GCA : *  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
reductionist20Table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : F  UCU : *  UAU : *  UGU : *
#   C  UUC : *  UCC : *  UAC : Y  UGC : C
#   A  UUA : *  UCA : S  UAA : *  UGA : *
#   G  UUG : *  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : L  CCC : *  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : *  CGA : R
#   G  CUG : *  CCG : P  CAG : Q  CGG : *
# A U  AUU : *  ACU : T  AAU : N  AGU : *
#   C  AUC : *  ACC : *  AAC : *  AGC : *
#   A  AUA : I  ACA : *  AAA : *  AGA : *
#   G  AUG : M  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : D  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : *  GCA : *  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
with open('res/ReductionistDict20AA.pickle', 'wb') as handle:
    pickle.dump(reductionist20, handle)

# %%
with open('res/ReductionistTable20AA.pickle', 'wb') as handle:
    pickle.dump(reductionist20Table, handle)

# %%
with open('res/ReductionistDict19AA.pickle', 'wb') as handle:
    pickle.dump(reductionist19, handle)

# %%
with open('res/ReductionistTable19AA.pickle', 'wb') as handle:
    pickle.dump(reductionist19Table, handle)

# %%
with open('res/ReductionistDict18AA.pickle', 'wb') as handle:
    pickle.dump(reductionist18, handle)

# %%
with open('res/ReductionistTable18AA.pickle', 'wb') as handle:
    pickle.dump(reductionist18Table, handle)

# %%
with open('res/ReductionistDict17AA.pickle', 'wb') as handle:
    pickle.dump(reductionist17, handle)

# %%
with open('res/ReductionistTable17AA.pickle', 'wb') as handle:
    pickle.dump(reductionist17Table, handle)

# %%
with open('res/ReductionistDict16AA.pickle', 'wb') as handle:
    pickle.dump(reductionist16, handle)

# %%
with open('res/ReductionistTable16AA.pickle', 'wb') as handle:
    pickle.dump(reductionist16Table, handle)

# %%
with open('res/ReductionistDict15AA.pickle', 'wb') as handle:
    pickle.dump(reductionist15, handle)

# %%
with open('res/ReductionistTable15AA.pickle', 'wb') as handle:
    pickle.dump(reductionist15Table, handle)
