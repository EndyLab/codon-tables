# %%
import numpy as np
from scipy.interpolate import interp1d as interp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from src.thunderflask import thunderflask
from src.bacteria import strain
from src.ffgen import ffgen
from src.ffgen_isaac import ffgen
from src.redGen import reductionist
from src.codonTable import codonTable
from src.codonUtils import utils
from src.bacteria import strain
import pickle
from src.codonOptimizer import tableOptimizer
from queue import Queue as queue
from random import choice
from matplotlib.colors import LinearSegmentedColormap as LSC
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cProfile
import copy
import random

# %%
#confirming the method works, both in ffgen and as its own script
table = codonTable(reductionist.redctionGen())
table2 =codonTable(ffgen.reductionist())

# %%
table.plot3d()

# %%
table2.plot3d()

# %%
table.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : *  UCU : *  UAU : Y  UGU : C
#   C  UUC : F  UCC : *  UAC : *  UGC : *
#   A  UUA : *  UCA : *  UAA : *  UGA : *
#   G  UUG : *  UCG : S  UAG : *  UGG : W
# C U  CUU : *  CCU : *  CAU : H  CGU : *
#   C  CUC : *  CCC : P  CAC : *  CGC : *
#   A  CUA : *  CCA : *  CAA : Q  CGA : *
#   G  CUG : L  CCG : *  CAG : *  CGG : R
# A U  AUU : *  ACU : *  AAU : *  AGU : *
#   C  AUC : I  ACC : *  AAC : N  AGC : *
#   A  AUA : *  ACA : T  AAA : *  AGA : *
#   G  AUG : M  ACG : *  AAG : K  AGG : *
# G U  GUU : *  GCU : *  GAU : D  GGU : *
#   C  GUC : *  GCC : *  GAC : *  GGC : G
#   A  GUA : *  GCA : A  GAA : E  GGA : *
#   G  GUG : V  GCG : *  GAG : *  GGG : *

# %%
table2.dictToTable()
# Out:
#            U        C        A        G
# U U  UUU : *  UCU : S  UAU : *  UGU : *
#   C  UUC : F  UCC : *  UAC : Y  UGC : C
#   A  UUA : *  UCA : *  UAA : *  UGA : *
#   G  UUG : L  UCG : *  UAG : *  UGG : W
# C U  CUU : *  CCU : P  CAU : *  CGU : *
#   C  CUC : *  CCC : *  CAC : H  CGC : *
#   A  CUA : *  CCA : *  CAA : Q  CGA : *
#   G  CUG : *  CCG : *  CAG : *  CGG : *
# A U  AUU : I  ACU : T  AAU : *  AGU : *
#   C  AUC : *  ACC : *  AAC : N  AGC : *
#   A  AUA : *  ACA : *  AAA : *  AGA : *
#   G  AUG : M  ACG : *  AAG : K  AGG : R
# G U  GUU : *  GCU : *  GAU : D  GGU : G
#   C  GUC : *  GCC : A  GAC : *  GGC : *
#   A  GUA : V  GCA : *  GAA : *  GGA : *
#   G  GUG : *  GCG : *  GAG : E  GGG : *
